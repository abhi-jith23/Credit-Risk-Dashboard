# %%
import os
from src.train import train_and_export

metrics = train_and_export()
metrics
# Out:
# /media/workhorse/Windows/MyWorkPlace/Master Data Science/Sem3/WorkshopII/Reproducibility/FinalProject/CreditRiskDashboard/notebooks
# {'n': 200,
#  'default_rate': 0.3,
#  'roc_auc': 0.8095238095238095,
#  'avg_precision': 0.6571793422793045,
#  'brier': 0.18425025548601415,
#  'roc_curve': {'fpr': [0.0,
#    0.0,
#    0.007142857142857143,
#    0.007142857142857143,
#    0.014285714285714285,
#    0.014285714285714285,
#    0.02142857142857143,
#    0.02142857142857143,
#    0.02857142857142857,
#    0.02857142857142857,
#    0.03571428571428571,
#    0.03571428571428571,
#    0.04285714285714286,
#    0.04285714285714286,
#    0.05714285714285714,
#    0.05714285714285714,
#    0.07142857142857142,
#    0.07142857142857142,
#    0.07857142857142857,
#    0.07857142857142857,
#    0.1,
#    0.1,
#    0.12857142857142856,
#    0.12857142857142856,
#    0.1357142857142857,
#    0.1357142857142857,
#    0.14285714285714285,
#    0.14285714285714285,
#    0.15,
#    0.15,
# ...
